# %%
import pandas as pd 
from matplotlib import pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')

df = dataset['train'].to_pandas()
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df_US = df[df['job_country'] == 'United States'].copy()
df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')
df_US_pivot = df_US.pivot_table(index = 'job_posted_month', columns = 'job_title_short', aggfunc='size')
df_US_pivot = df_US_pivot.reset_index()
df_US_pivot['job_posted_month_no'] = pd.to_datetime(df_US_pivot['job_posted_month'], format='%B').dt.month
df_US_pivot = df_US_pivot.sort_values('job_posted_month_no')
df_US_pivot = df_US_pivot.set_index('job_posted_month')
df_US_pivot = df_US_pivot.drop(columns = 'job_posted_month_no')

df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        527              36          8494
# February                       447              24          6124
# March                          438              19          6218
# April                          565              40          6049
# May                            279              20          4993
# June                           446              32          5683
# July                           581              39          5201
# August                         903              39          6634
# September                      897              50          4639
# October                        932              48          5271
# November                       719              36          4531
# December                       648              40          3979
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2655            6915                         60
# February                   3060            4956                         56
# March                      3183            4779                         59
# April                      2801            4867                         51
# May                        2976            4377                         49
# June                       2893            4645                         48
# July                       2570            4876                         65
# August                     3269            6318                         68
# September                  3224            4568                        113
# October                    3015            4882                        101
# November                   2793            4175                        132
# December                   2641            3472                        119
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                          1544                   773
# February                         1258                   878
# March                            1114                   829
# April                            1025                   781
# May                               839                   746
# June                             1009                   812
# July                              883                   747
# August                           1186                   903
# September                         805                   775
# October                           871                   672
# November                          656                   684
# December                          601                   689
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                            1552                114
# February                           1127                 90
# March                              1150                115
# April                               991                112
# May                                 914                 90
# June                               1033                 93
# July                               1095                153
# August                             1515                194
# September                          1014                228
# October                             987                219
# November                            816                194
# December                            752                212

# %%
df_US_software_pivot = pd.read_csv("https://lukeb.co/software_csv", index_col="job_posted_month")

df_US_software_pivot
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# March                             5814            4159
# April                             7232            4220
# May                               6718            4980
# June                              5902            4781
# July                              6839            4344
# August                            7413            4104
# September                         6139            4094
# October                           5026            4389
# November                          5653            4099
# December                          6731            4367

# %%
df_US_merged = df_US_pivot.merge(df_US_pivot, on = "job_posted_month")
df_US_merged
# Out:
# job_title_short   Business Analyst_x  Cloud Engineer_x  Data Analyst_x  \
# job_posted_month
# January                          527                36            8494
# February                         447                24            6124
# March                            438                19            6218
# April                            565                40            6049
# May                              279                20            4993
# June                             446                32            5683
# July                             581                39            5201
# August                           903                39            6634
# September                        897                50            4639
# October                          932                48            5271
# November                         719                36            4531
# December                         648                40            3979
#
# job_title_short   Data Engineer_x  Data Scientist_x  \
# job_posted_month
# January                      2655              6915
# February                     3060              4956
# March                        3183              4779
# April                        2801              4867
# May                          2976              4377
# June                         2893              4645
# July                         2570              4876
# August                       3269              6318
# September                    3224              4568
# October                      3015              4882
# November                     2793              4175
# December                     2641              3472
#
# job_title_short   Machine Learning Engineer_x  Senior Data Analyst_x  \
# job_posted_month
# January                                    60                   1544
# February                                   56                   1258
# March                                      59                   1114
# April                                      51                   1025
# May                                        49                    839
# June                                       48                   1009
# July                                       65                    883
# August                                     68                   1186
# September                                 113                    805
# October                                   101                    871
# November                                  132                    656
# December                                  119                    601
#
# job_title_short   Senior Data Engineer_x  Senior Data Scientist_x  \
# job_posted_month
# January                              773                     1552
# February                             878                     1127
# March                                829                     1150
# April                                781                      991
# May                                  746                      914
# June                                 812                     1033
# July                                 747                     1095
# August                               903                     1515
# September                            775                     1014
# October                              672                      987
# November                             684                      816
# December                             689                      752
#
# job_title_short   Software Engineer_x  Business Analyst_y  Cloud Engineer_y  \
# job_posted_month
# January                           114                 527                36
# February                           90                 447                24
# March                             115                 438                19
# April                             112                 565                40
# May                                90                 279                20
# June                               93                 446                32
# July                              153                 581                39
# August                            194                 903                39
# September                         228                 897                50
# October                           219                 932                48
# November                          194                 719                36
# December                          212                 648                40
#
# job_title_short   Data Analyst_y  Data Engineer_y  Data Scientist_y  \
# job_posted_month
# January                     8494             2655              6915
# February                    6124             3060              4956
# March                       6218             3183              4779
# April                       6049             2801              4867
# May                         4993             2976              4377
# June                        5683             2893              4645
# July                        5201             2570              4876
# August                      6634             3269              6318
# September                   4639             3224              4568
# October                     5271             3015              4882
# November                    4531             2793              4175
# December                    3979             2641              3472
#
# job_title_short   Machine Learning Engineer_y  Senior Data Analyst_y  \
# job_posted_month
# January                                    60                   1544
# February                                   56                   1258
# March                                      59                   1114
# April                                      51                   1025
# May                                        49                    839
# June                                       48                   1009
# July                                       65                    883
# August                                     68                   1186
# September                                 113                    805
# October                                   101                    871
# November                                  132                    656
# December                                  119                    601
#
# job_title_short   Senior Data Engineer_y  Senior Data Scientist_y  \
# job_posted_month
# January                              773                     1552
# February                             878                     1127
# March                                829                     1150
# April                                781                      991
# May                                  746                      914
# June                                 812                     1033
# July                                 747                     1095
# August                               903                     1515
# September                            775                     1014
# October                              672                      987
# November                             684                      816
# December                             689                      752
#
# job_title_short   Software Engineer_y
# job_posted_month
# January                           114
# February                           90
# March                             115
# April                             112
# May                                90
# June                               93
# July                              153
# August                            194
# September                         228
# October                           219
# November                          194
# December                          212

# %%
top_5 = df_US_merged.sum().sort_values(ascending = False).head().index.to_list()
top_5
# Out:
# ['Data Analyst_x',
#  'Data Analyst_y',
#  'Data Scientist_x',
#  'Data Scientist_y',
#  'Data Engineer_y']

# %%
df_US_merged[top_5].plot(kind='line')
# Out:
# <AxesSubplot:xlabel='job_posted_month'>
